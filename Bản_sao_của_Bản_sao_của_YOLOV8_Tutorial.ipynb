# %% [markdown]
# <a href="https://colab.research.google.com/github/NguyenChauLeDung/lab-agile-planning/blob/main/B%E1%BA%A3n_sao_c%E1%BB%A7a_B%E1%BA%A3n_sao_c%E1%BB%A7a_YOLOV8_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.59 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.6/112.6 GB disk)

# %%
# Run inference on an image with YOLOv8\
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/zidane.jpg'
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 162MB/s]
# Ultralytics 8.3.59 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100% 49.2k/49.2k [00:00<00:00, 10.8MB/s]
# image 1/1 /content/zidane.jpg: 384x640 2 persons, 1 tie, 69.9ms
# Speed: 14.0ms preprocess, 69.9ms inference, 804.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
! unrar x  /content/coco128.rar
# Out:
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from /content/coco128.rar
#
# Creating    __MACOSX                                                  OK
#   OK
# Creating    __MACOSX/coco128                                          OK
#   OK
# Creating    __MACOSX/coco128/images                                   OK
#   OK
# Creating    __MACOSX/coco128/images/train2017                         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
# Train YOLOv8n on COCO8 for 3 epochs
# !yolo train model= yolov8n.pt data=coco128.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.59 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Run inference on an image with YOLOv8\
# !yolo predict model=/content/runs/detect/train4/weights/best.pt source='/content/IMG_0850.jpeg'
# Out:
# Ultralytics 8.3.58 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/1 /content/IMG_0850.jpeg: 480x640 6 persons, 66.4ms
# Speed: 5.5ms preprocess, 66.4ms inference, 1052.3ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
